# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrew8726/cybersecurity-portfolio/blob/main/Andrews_python_quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The content of the following cell install the pywars client into this notebook. It must be executed once during the lifetime of a notebooks execution.  If you save and reopen the notebook you will need to execute again, but otherwise you only need to run it once.

# %%
#Import and/or install the pywars client
# !git clone --branch version5 https://github.com/markbaggett/pyWars
# !pip install ./pyWars

#Mount the google drive in colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Cloning into 'pyWars'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 193 (delta 5), reused 11 (delta 3), pack-reused 177 (from 1)
# Receiving objects: 100% (193/193), 38.43 KiB | 4.80 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# Processing ./pyWars
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from pywars==5.0.4) (2.32.4)
# Requirement already satisfied: rich>=9.1.0 in /usr/local/lib/python3.12/dist-packages (from pywars==5.0.4) (13.9.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->pywars==5.0.4) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->pywars==5.0.4) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->pywars==5.0.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->pywars==5.0.4) (2026.5.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=9.1.0->pywars==5.0.4) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=9.1.0->pywars==5.0.4) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=9.1.0->pywars==5.0.4) (0.1.2)
# Building wheels for collected packages: pywars
#   Building wheel for pywars (pyproject.toml) ... done
#   Created wheel for pywars: filename=pywars-5.0.4-py3-none-any.whl size=8830 sha256=2b0d8d5bf06205c5c089c37a6d765ed989f999b4327adfc13c92660153190344
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dh45cynz/wheels/76/37/a7/9cfc81a1d79f0ceb96262c579268e440f053bf7c6cd9142399
# Successfully built pywars
# Installing collected packages: pywars
# Successfully installed pywars-5.0.4
# Mounted at /content/drive

# %% [markdown]
# This next command must be run once to configure your pyWars server and to login.  Be sure to put your username and password in the .login() function.  Before running this you must change the contents of the three variables below to reflect your account information provided by SANS.

# %%
#Set the following three variables and execute this cell
HOSTNAME = 'python.sans.edu'
USERNAME = 'pywars_login_10047'
PASSWORD = 'SPtKjdwWcHmxRHS5W25H'

#This will create your pywars client object and store in the variable d
import pywars
d = pywars.Client(f"https://{HOSTNAME}:10000")
d.file_location="/content/drive/MyDrive"
d.login(USERNAME,PASSWORD)
# Out:
# 'Login Success'

# %% [markdown]
# In this lab you will complete all of the labs that have "quiz2" in the name.  The next cell uses a for loop to print just those with "quiz2" in the name. Run it to see a list of all of the challenge you must complete.

# %%
for each_name in d.names:
    if each_name.startswith("quiz2"):
        print(f"You must complete {each_name}")

# %% [markdown]
# # **WARNING**
# ## These are quiz questions. You can only submit `.answer()` once per question. Read the question carefully. Your ability to follow instructions and use Python to submit answers is part of the grade. If you accidentally submit an incorrect answer, it is wrong.

# %%
#Ask for the question and data together to avoid confusion.
qname = "quiz???"
d.question(qname)
print(d.data(qname))

# %% [markdown]
# Carefully consider your answer. Remember, you get one attempt per question. When you are ready submit your answer.
#
# Note: the next cell is commented out so that you do not accidentally run it.

# %%
#d.answer( your answer here )
